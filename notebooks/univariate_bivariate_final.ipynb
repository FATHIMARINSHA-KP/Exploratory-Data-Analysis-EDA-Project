# %%
import pandas as pd 

import numpy as np

import seaborn as sns 

import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\A S S A U L T\Desktop\eda - project\data\interim\customer_cleaned_day2.csv")

df.head()
# Out:
#    customer_id telecom_partner gender   age           state       city  \
# 0       230797          Airtel      M  20.0      Tamil Nadu      Delhi
# 1       191986        Vodafone      F  68.0     Uttarakhand      Delhi
# 2        18779        Vodafone      M  30.0             Goa     Mumbai
# 3       241017        Vodafone      M  22.0  Madhya Pradesh    Chennai
# 4       136495    Reliance Jio      M  63.0         Tripura  Bangalore
#
#    pincode date_of_registration  num_dependents  estimated_salary  calls_made  \
# 0   285677           2023-03-01               2          104752.0          38
# 1   679704           2022-08-18               2           71706.0          43
# 2   837926           2020-04-03               4          137473.0          -2
# 3   679346           2023-04-21               0           58245.0          32
# 4   839738           2021-11-14               4           85609.0          68
#
#    sms_sent  data_used  churn  estimated_salary_log
# ...

# %% [markdown]
# # UNIVARAIATE ANALYSIS

# %% [markdown]
# ### Numerical Univariate Analysis

# %%
# Age Distribution

plt.figure(figsize=(8,5))

sns.histplot(df['age'],bins =30,kde =True)

plt.title("Age Distribution")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\age_distribution.png")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df['age'])

plt.title("Age Boxplot")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\age_Boxplot.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Most customers belong to middle age groups

- Very few customers are very young or very old

- Middle-aged customers form the majority of users

- Age-based marketing can improve customer targeting

# %%
# Salary Distribution

plt.figure(figsize=(8,5))

sns.histplot(df['estimated_salary'],bins =30, kde = True)

plt.title("Salary Distribution")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\Salary_distribution.png")

plt.show()

# %%
sns.boxplot(x=np.log1p(df['estimated_salary']))

plt.title('Salary Boxplot')

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\EstimatedSalary_Boxplot.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Most customers have moderate salary levels

- Some customers have very high salaries

- Majority of customers belong to middle income groups

- High income customers are fewer in number

# %%
# Data Usage Distribution

plt.figure(figsize=(8,5))

sns.histplot(df['data_used'], bins=30, kde=True)

plt.title("Data Usage Distribution")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\DataUsage_Distribution.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Most customers use moderate amounts of mobile data

- A few customers show very high data usage

- Regular data users form the majority

- Heavy internet users are smaller in number

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df['calls_made'])

plt.title("Calls Made Boxplot")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\CallsMade_Boxplot.png")


plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Calling activity differs across customers

- Some customers make very high numbers of calls

- Most customers have normal calling behavior

- Highly active callers are limited

# %% [markdown]
# ###  Categorical Univariate Analysis

# %%
# Telecom Partner Distribution

plt.figure(figsize=(8,5))

sns.countplot(x='telecom_partner', data=df)

plt.title("Telecom Partner Distribution")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\TelecomPartner_Distribution.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Customer distribution across telecom providers is balanced

- Airtel, BSNL, Vodafone, and Reliance Jio have similar counts

- No telecom provider dominates the dataset

- Provider comparison becomes more meaningful

# %%
# Gender Distribution

plt.figure(figsize=(6,4))

sns.countplot(x='gender', data=df)

plt.title("Gender Distribution")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\Gender_Distribution.png")

plt.show()

# %%
df['gender'].value_counts()
# Out:
# gender
# M    11980
# F     8038
# Name: count, dtype: int64

# %% [markdown]
# ## Findings & Insights

# %%
- Male customers are more than female customers

- Dataset contains good gender representation

- Gender-based analysis becomes more reliable

# %%
# Churn Distribution

plt.figure(figsize=(6,4))

sns.countplot(x='churn', data=df)

plt.title("Churn Distribution")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\Churn_Distribution.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Most customers did not churn

- Churned customers form a smaller group

- Majority of customers remain with telecom providers

- Churn prediction can help identify risk customers

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# ### Numeric vs Numeric

# %%
# Calls Made vs Data Used

plt.figure(figsize=(8,5))

sns.scatterplot( x='calls_made', y='data_used',data=df)

plt.title("Calls Made vs Data Used")

plt.xlabel("Calls Made")

plt.ylabel("Data Used")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\calls_vs_data_used.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Calls made and data usage show weak relationship

- Customer telecom usage behavior varies significantly

- Many customers have low call activity but varying internet usage

- High calling customers do not always consume high data

# %%
plt.figure(figsize=(8,5))

sns.scatterplot( x='sms_sent',y='data_used',data=df)

plt.title("SMS Sent vs Data Used")

plt.xlabel("SMS Sent")

plt.ylabel("Data Used")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\sms_vs_data_used.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Customers who send more SMS do not always use more internet data

- Relationship is Weak

- Messaging activity is linked with overall telecom engagement

- Active users consume more services

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(x='calls_made',y='sms_sent', data=df)

plt.title("Calls Made vs SMS Sent")

plt.xlabel("Calls Made")

plt.ylabel("SMS Sent")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\calls_vs_sms_sent.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Calls made and SMS sent show weak relationship

- Customers display different communication preferences

- Some customers prefer calling while others prefer texting

- Very few customers are highly active in both calls and SMS

# %%
plt.figure(figsize=(10,6))

sns.heatmap( df.corr(numeric_only=True),annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\correlation_heatmap.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Numerical columns show low to moderate correlations

- Calls made and data usage show positive correlations

- Telecom services are related through customer activity

- Correlation analysis helps identify usage behavior patterns

# %% [markdown]
# ### Numeric–categorical

# %%
# Telecom Partner vs Data Used

sns.boxplot( x='telecom_partner', y='data_used', data=df)

plt.title("Telecom Partner vs Data Used")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\telecom_partner_vs_data_used.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Data usage is similar across telecom providers

- Some variation exists among customer groups

- Internet usage behavior is fairly consistent across providers

- Heavy data users exist in all telecom companies

# %%
# Churn vs Calls Made

plt.figure(figsize=(8,5))

sns.boxplot(x='churn', y='calls_made', data=df)

plt.title("Churn vs Calls Made")

plt.xlabel("Churn (0 = Not Churned, 1 = Churned)")

plt.ylabel("Calls Made")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\Churn_vs_CallsMade.png")

plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Calling activity differs between churned and retained customers

- Customers with lower call activity may be more likely to churn

- Highly active calling users appear more engaged with telecom services

- Some customers show extremely high calling behavior (outliers)

# %%
# Churn vs Data Used

plt.figure(figsize=(8,5))

sns.boxplot(x='churn',y='data_used',data=df)

plt.title("Churn vs Data Used")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\churn_vs_data_used.png")


plt.show()

# %% [markdown]
# ## Findings & Insights

# %%
- Data usage differs between churned and non-churned customers

- Some high data users are less likely to churn

- Customer engagement may affect churn behavior

- Data usage patterns help identify churn risk customers

# %%
# Gender vs Churn

plt.figure(figsize=(8,5))

sns.countplot(x='gender',hue='churn',data=df)

plt.title("Gender vs Churn")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.savefig(r"C:\Users\A S S A U L T\Desktop\eda - project\reports\figures\gender_vs_churn.png")

plt.show()

# %%
(pd.crosstab(df['gender'], df['churn'], normalize='index') * 100).round(2)
# Out:
# churn       0      1
# gender
# F       79.15  20.85
# M       80.46  19.54

# %% [markdown]
# ## Findings & Insights

# %%
- Churn behavior differs between male and female customers

- One gender shows slightly higher churn levels

- Gender may influence customer retention behavior

- Demographic analysis helps identify churn patterns

# %% [markdown]
# # Overall Findings

# %%
# Overall Findings

1.Most customers show moderate telecom usage across calls, SMS, and data services.
    
2.Customer distribution across telecom providers is fairly balanced.
    
3.Calls made, SMS activity, and data usage generally show weak relationships with each other.
    
4.Some numerical columns contain noticeable outliers and skewed distributions.
    
5.Churn behavior varies slightly across customer groups and demographics.

# Overall Insights

1. Customers use telecom services differently based on their communication preferences.
    
2.Some customers prefer calls, while others prefer SMS or internet services.
    
3.Customer demographics alone may not strongly explain churn behavior.
    
4.Data cleaning and preprocessing improved dataset quality and analysis reliability.
    
5.Customer behavior analysis can help telecom companies improve retention strategies and customer segmentation.
